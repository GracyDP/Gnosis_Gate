# %%
import pandas as pd

df = pd.read_csv("vehicle0_1.csv")
df
# Out:
#      Attr1  Attr2  Attr3  Attr4  Attr5  Attr6  Attr7  Attr8  Attr9  Attr10  \
# 0       85     45     80    154     64      9    147     45     19     148
# 1       93     40     73    139     58      6    136     49     18     138
# 2       86     40     66    139     59      7    122     54     17     139
# 3       91     38     70    160     66     25    140     47     18     139
# 4       98     38     66    130     55      7    130     51     18     138
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...     ...
# 194     90     48     78    134     56     11    160     43     20     167
# 195     92     40     62    144     59      8    127     52     17     139
# 196     85     47     75    121     53      9    157     44     20     165
# 197     93     43     78    162     64      8    137     48     18     145
# 198     89     47     84    133     55     11    157     44     20     160
#
# ...

# %%
df2 = df[["Attr{}".format(i) for i in [4,5,12]]]
df2.to_csv("vehicle0_1_lite.csv", sep=",", index=False)

# %%
df2 = pd.read_csv("vehicle0_1_lite.csv")
df2
# Out:
#      Attr4  Attr5  Attr12
# 0      154     64     324
# 1      139     58     275
# 2      139     59     225
# 3      160     66     296
# 4      130     55     251
# ..     ...    ...     ...
# 194    134     56     366
# 195    144     59     241
# 196    121     53     358
# 197    162     64     281
# 198    133     55     354
#
# [199 rows x 3 columns]
